# %% [markdown]
# # Scraping an undocumented API: a BBC election results map
#
# The BBC's election results page at https://www.bbc.co.uk/news/election/2023/england/results presents election results on a map. This notebook explains how to fetch that data and export it as a CSV.
#
# It also explains how to navigate JSON files, flatten branches at different levels, common errors you are likely to come across, and how to tackle those.

# %% [markdown]
# ## Using the Inspector
#
# As is often the case with maps, the data is fetched from an external file, and you can find that data file by [looking in the Inspector's Network tab](https://developer.chrome.com/docs/devtools/network).
#
# Open the Inspector by making sure you are in Chrome or Firefox, right-clicking anywhere on the page and selecting **Inspect**. The first tab in the inspector is 'Elements' - switch to the 'Network' tab instead.
#
# The Network tab shows all the files that a webpage loads - but it has to be open to be 'recording', so once you've opened the Inspector and gone to the Network tab, make sure you refresh the page so that it can record all the files.
#
# By default the Network tab shows 'All' files, but you can also click on **XHR** (or **Fetch/XHR** in Chrome) to only show likely data requests. Sort by size to bring the largest to the top.
#
# In that view there are a few files that might contain useful data: `councils` and `results` and `council_control_history` are all likely.
#
# You can right-click on these and open them in a new tab to see what they contain. They are all JSON files so use Firefox to automatically 'prettify' them (make them easier to read) or install the Chrome extension [JSONView](https://jsonview.com/) to prettify JSON in that browser.
#
# We are going to import the `councils` file, which the Inspector tells us is at https://static.files.bbci.co.uk/elections/archive/news/election/2023/england/councils

# %% [markdown]
# ## Importing the `councils` JSON
#
# First, we need to store the URL of the JSON we want to import.

# %%
#store the URL of the JSON file
jsonurl = "https://static.files.bbci.co.uk/elections/archive/news/election/2023/england/councils"

# %% [markdown]
# ## Import libraries
#
# We are going to try to import this using the `read_json()` function from the `pandas` library, so we need to import the `pandas` library first.

# %%
#import the pandas library so we can use its read_json() function
import pandas as pd

# %% [markdown]
# ## Try to read the JSON into a `pandas` data frame
#
# Now we try to read the JSON file at the URL we've stored in the variable `jsonurl` - but we get an error.

# %%
#read the JSON from the URL in 'jsonurl'
pd.read_json(jsonurl)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-82b5c980dd42> in <cell line: 1>()
# ----> 1 pd.read_json(jsonurl)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     782         return json_reader
#     783     else:
# --> 784         return json_reader.read()
#     785
#     786
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read(self)
#     973                         obj = self._get_object_parser(self._combine_lines(data_lines))
#     974                 else:
# --> 975                     obj = self._get_object_parser(self.data)
#     976                 if self.dtype_backend is not lib.no_default:
#     977                     return obj.convert_dtypes(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     999         obj = None
#    1000         if typ == "frame":
# -> 1001             obj = FrameParser(json, **kwargs).parse()
#    1002
#    1003         if typ == "series" or obj is None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in parse(self)
#    1132
#    1133     def parse(self):
# -> 1134         self._parse()
#    1135
#    1136         if self.obj is None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in _parse(self)
#    1317
#    1318         if orient == "columns":
# -> 1319             self.obj = DataFrame(
#    1320                 loads(json, precise_float=self.precise_float), dtype=None
#    1321             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     707         elif isinstance(data, dict):
#     708             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710         elif isinstance(data, ma.MaskedArray):
#     711             from numpy.ma import mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     479             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     480
# --> 481     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     482
#     483
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     113         # figure out the index, if necessary
#     114         if index is None:
# --> 115             index = _extract_index(arrays)
#     116         else:
#     117             index = ensure_index(index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     653         lengths = list(set(raw_lengths))
#     654         if len(lengths) > 1:
# --> 655             raise ValueError("All arrays must be of the same length")
#     656
#     657         if have_dicts:
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# ### Why do we get the error 'All arrays must be of the same length'?
#
# The error says this:
#
# `ValueError: All arrays must be of the same length`
#
# This is because the JSON file doesn't have a simple enough structure for `read_json()` to easily convert it to a data frame.
#
# Instead we are going to need another approach: the `requests` library.

# %% [markdown]
# ## Using `requests` to fetch JSON
#
# The `requests` library's `get()` function is only concerned with fetching the file, not converting it to a dataframe.
#
# First, we need to import the library.

# %%
#import the requests library
import requests

# %% [markdown]
# When we use the `get()` function without storing the results we get a 'response' with a number: this is a status code that indicates whether the request was successful or not (you can [find a list here](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status). The number 200 indicates success.

# %%
#use the get() function to fetch the file at the URL we stored
requests.get(jsonurl)
# Out:
# <Response [200]>

# %% [markdown]
# ### Working with the requests 'object'
#
# We need to store the results of the `get()` function in a variable. Because it was created by a `requests` function, we call it a 'requests object'. An object created with `requests` has special properties that we can access.
#
# We call that variable 'response':

# %%
#use the get() function to fetch the file at the URL we stored
#store in a variable called 'response'
response = requests.get(jsonurl)
#show the variable - it'll be 200 again
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Requests [has a specific method for working with JSON files](https://www.geeksforgeeks.org/response-json-python-requests/): `.json()`
#
# By adding `.json()` to the end of the variable the contents will be parsed as JSON.

# %%
#use the .json() method to extract the contents as JSON
#store in a variable called jsonresponse
jsonresponse = response.json()
#show that variable
print(jsonresponse)
# Out:
# {'metadata': {'title': 'Councils in local elections 2023 in England - A-Z', 'areaId': '', 'pageType': 'a_to_z', 'languageCode': 'en', 'description': 'Get the latest news and election results in the 2023 election from BBC News', 'area': {'name': '', 'kind': '', 'parentId': ''}, 'uri': '/news/election/2023/england/councils', 'parent': {'name': '', 'uri': ''}}, 'language': 'en', 'heading': 'England Councils A-Z', 'campaignMode': False, 'bannerUri': '/news/election/2023/england/banner', 'logoUrl': 'https://static.files.bbci.co.uk/elections/images/england2023locals/election-logo-en.svg', 'links': None, 'key': [{'id': 'letter-a', 'name': 'A', 'enabled': True}, {'id': 'letter-b', 'name': 'B', 'enabled': True}, {'id': 'letter-c', 'name': 'C', 'enabled': True}, {'id': 'letter-d', 'name': 'D', 'enabled': True}, {'id': 'letter-e', 'name': 'E', 'enabled': True}, {'id': 'letter-f', 'name': 'F', 'enabled': True}, {'id': 'letter-g', 'name': 'G', 'enabled': True}, {'id': 'letter-h', 'name': 'H', 'enabled': True}, {'id': 'letter-i', 'name': 'I', 'enabled': True}, {'id': 'letter-j', 'name': 'J', 'enabled': False}, {'id': 'letter-k', 'name': 'K', 'enabled': True}, {'id': 'letter-l', 'name': 'L', 'enabled': True}, {'id': 'letter-m', 'name': 'M', 'enabled': True}, {'id': 'letter-n', 'name': 'N', 'enabled': True}, {'id': 'letter-o', 'name': 'O', 'enabled': True}, {'id': 'letter-p', 'name': 'P', 'enabled': True}, {'id': 'letter-q', 'name': 'Q', 'enabled': False}, {'id': 'letter-r', 'name': 'R', 'enabled': True}, {'id': 'letter-s', 'name': 'S', 'enabled': True}, {'id': 'letter-t', 'name': 'T', 'enabled': True}, {'id': 'letter-u', 'name': 'U', 'enabled': True}, {'id': 'letter-v', 'name': 'V', 'enabled': True}, {'id': 'letter-w', 'name': 'W', 'enabled': True}, {'id': 'letter-x', 'name': 'X', 'enabled': False}, {'id': 'letter-y', 'name': 'Y', 'enabled': True}, {'id': 'letter-z', 'name': 'Z', 'enabled': False}], 'groups': [{'id': 'letter-a', 'heading': 'A', 'cards': [{'title': 'Amber Valley', 'href': '/news/election/2023/england/councils/E07000032', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#E91D0E', 'prevColour': '#0575C9', 'flash': 'LABOUR GAIN FROM CONSERVATIVE', 'longFlash': '2023 Labour gain from Conservative', 'textColour': '#FFFFFF', 'partyName': 'Labour', 'flashBold': 'LABOUR GAIN', 'flashRegular': ' FROM CONSERVATIVE', 'winnerPartyCode': 'LAB', 'prevWinnerPartyCode': 'CON'}, 'context': None}, {'title': 'Arun', 'href': '/news/election/2023/england/councils/E07000224', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}, {'title': 'Ashfield', 'href': '/news/election/2023/england/councils/E07000170', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#BABABA', 'prevColour': '#BABABA', 'flash': 'ASHFIELD INDEPENDENTS HOLD', 'longFlash': '2023 Ashfield Independents hold, from previous year', 'textColour': '#3F3F42', 'partyName': 'Ashfield Independents', 'flashBold': 'ASHFIELD INDEPENDENTS HOLD', 'flashRegular': '', 'winnerPartyCode': 'ASH', 'prevWinnerPartyCode': 'ASH'}, 'context': None}, {'title': 'Ashford', 'href': '/news/election/2023/england/councils/E07000105', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}], 'backToTop': ...

# %% [markdown]
# More specifically, it will be turned into a [**dictionary** variable](https://www.w3schools.com/python/python_dictionaries.asp), which works in the same way as JSON.

# %%
#use the type() function to check what type of variable this is
type(jsonresponse)
# Out:
# dict

# %% [markdown]
# ## Navigating the JSON
#
# Now that we have our JSON (or dictionary), we need to drill down to part of the JSON that we can store as a data frame.
#
# A good place to start is by listing the **keys** (branches) at the top of the JSON. We can do this by adding `.keys()` to the end of any dictionary variable.

# %%
jsonresponse.keys()
# Out:
# dict_keys(['metadata', 'language', 'heading', 'campaignMode', 'bannerUri', 'logoUrl', 'links', 'key', 'groups', 'labels'])

# %% [markdown]
# It's useful to have [the URL that the data came from](https://static.files.bbci.co.uk/elections/archive/news/election/2023/england/councils) open in a browser (Firefox or Chrome with JSONView) so you can see the structure and where you want to go in it.
#
# In this case we want to go into the `groups` branch.
#
# To do that, we name the variable, and then the branch in square brackets like so:

# %%
#show the groups branch
print(jsonresponse['groups'])
# Out:
# [{'id': 'letter-a', 'heading': 'A', 'cards': [{'title': 'Amber Valley', 'href': '/news/election/2023/england/councils/E07000032', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#E91D0E', 'prevColour': '#0575C9', 'flash': 'LABOUR GAIN FROM CONSERVATIVE', 'longFlash': '2023 Labour gain from Conservative', 'textColour': '#FFFFFF', 'partyName': 'Labour', 'flashBold': 'LABOUR GAIN', 'flashRegular': ' FROM CONSERVATIVE', 'winnerPartyCode': 'LAB', 'prevWinnerPartyCode': 'CON'}, 'context': None}, {'title': 'Arun', 'href': '/news/election/2023/england/councils/E07000224', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}, {'title': 'Ashfield', 'href': '/news/election/2023/england/councils/E07000170', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#BABABA', 'prevColour': '#BABABA', 'flash': 'ASHFIELD INDEPENDENTS HOLD', 'longFlash': '2023 Ashfield Independents hold, from previous year', 'textColour': '#3F3F42', 'partyName': 'Ashfield Independents', 'flashBold': 'ASHFIELD INDEPENDENTS HOLD', 'flashRegular': '', 'winnerPartyCode': 'ASH', 'prevWinnerPartyCode': 'ASH'}, 'context': None}, {'title': 'Ashford', 'href': '/news/election/2023/england/councils/E07000105', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}], 'backToTop': True}, {'id': 'letter-b', 'heading': 'B', 'cards': [{'title': 'Babergh', 'href': '/news/election/2023/england/councils/E07000200', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}, {'title': 'Barnsley', 'href': '/news/election/2023/england/councils/E08000016', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#E91D0E', 'prevColour': '#E91D0E', 'flash': 'LABOUR HOLD', 'longFlash': '2023 Labour hold, from previous year', 'textColour': '#FFFFFF', 'partyName': 'Labour', 'flashBold': 'LABOUR HOLD', 'flashRegular': '', 'winnerPartyCode': 'LAB', 'prevWinnerPartyCode': 'LAB'}, 'context': None}, {'title': 'Basildon', 'href': '/news/election/2023/england/councils/E07000066', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#0575C9', 'prevColour': '#0575C9', 'flash': 'CONSERVATIVE HOLD', 'longFlash': '2023 Conservative hold, from previous year', 'textColour': '#FFFFFF', 'partyName': 'Conservative', 'flashBold': 'CONSERVATIVE HOLD', 'flashRegular': '', 'winnerPartyCode': 'CON', 'prevWinnerPartyCode': 'CON'}, 'context': None}, {'title': 'Basingstoke & Deane', 'href': '/news/election/2023/england/councils/E07000084', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANG ...

# %% [markdown]
# At this point if we try to show the keys again, we get an error, because this branch doesn't have any keys - instead, it has a list.

# %%
#try to show the keys of the 'groups' branch
print(jsonresponse['groups'].keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a7b0e9fffd71> in <cell line: 1>()
# ----> 1 print(jsonresponse['groups'].keys())
#
# AttributeError: 'list' object has no attribute 'keys'

# %% [markdown]
# Instead, then, we can use an index like `[0]` to access the first item in that list.

# %%
#show the first item in the groups branch
print(jsonresponse['groups'][0])
# Out:
# {'id': 'letter-a', 'heading': 'A', 'cards': [{'title': 'Amber Valley', 'href': '/news/election/2023/england/councils/E07000032', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#E91D0E', 'prevColour': '#0575C9', 'flash': 'LABOUR GAIN FROM CONSERVATIVE', 'longFlash': '2023 Labour gain from Conservative', 'textColour': '#FFFFFF', 'partyName': 'Labour', 'flashBold': 'LABOUR GAIN', 'flashRegular': ' FROM CONSERVATIVE', 'winnerPartyCode': 'LAB', 'prevWinnerPartyCode': 'CON'}, 'context': None}, {'title': 'Arun', 'href': '/news/election/2023/england/councils/E07000224', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}, {'title': 'Ashfield', 'href': '/news/election/2023/england/councils/E07000170', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#BABABA', 'prevColour': '#BABABA', 'flash': 'ASHFIELD INDEPENDENTS HOLD', 'longFlash': '2023 Ashfield Independents hold, from previous year', 'textColour': '#3F3F42', 'partyName': 'Ashfield Independents', 'flashBold': 'ASHFIELD INDEPENDENTS HOLD', 'flashRegular': '', 'winnerPartyCode': 'ASH', 'prevWinnerPartyCode': 'ASH'}, 'context': None}, {'title': 'Ashford', 'href': '/news/election/2023/england/councils/E07000105', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}], 'backToTop': True}

# %% [markdown]
# And we can then try to access the keys of that item:

# %%
#show the keys of the first item in the groups branch
print(jsonresponse['groups'][0].keys())
# Out:
# dict_keys(['id', 'heading', 'cards', 'backToTop'])

# %% [markdown]
# This trial-and-error process of trying to access keys and/or a list item is a good way for navigating a JSON object until you get to the branch you want.

# %%
#show the keys of the first item in the groups branch
print(jsonresponse['groups'][0]['cards'])
# Out:
# [{'title': 'Amber Valley', 'href': '/news/election/2023/england/councils/E07000032', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#E91D0E', 'prevColour': '#0575C9', 'flash': 'LABOUR GAIN FROM CONSERVATIVE', 'longFlash': '2023 Labour gain from Conservative', 'textColour': '#FFFFFF', 'partyName': 'Labour', 'flashBold': 'LABOUR GAIN', 'flashRegular': ' FROM CONSERVATIVE', 'winnerPartyCode': 'LAB', 'prevWinnerPartyCode': 'CON'}, 'context': None}, {'title': 'Arun', 'href': '/news/election/2023/england/councils/E07000224', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}, {'title': 'Ashfield', 'href': '/news/election/2023/england/councils/E07000170', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#BABABA', 'prevColour': '#BABABA', 'flash': 'ASHFIELD INDEPENDENTS HOLD', 'longFlash': '2023 Ashfield Independents hold, from previous year', 'textColour': '#3F3F42', 'partyName': 'Ashfield Independents', 'flashBold': 'ASHFIELD INDEPENDENTS HOLD', 'flashRegular': '', 'winnerPartyCode': 'ASH', 'prevWinnerPartyCode': 'ASH'}, 'context': None}, {'title': 'Ashford', 'href': '/news/election/2023/england/councils/E07000105', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}]

# %% [markdown]
# ## Converting to a data frame
#
# Once we have found the branch we want, we can convert it to a `pandas` data frame.
#
# The most obvious function for creating a data frame from a dictionary is `pd.DataFrame.from_dict()`
#
# We can try that with the branch we've arrived at:

# %%
#convert the 'cards' branch of jsonresponse into a dataframe
pd.DataFrame.from_dict(jsonresponse['groups'][0]['cards'])
# Out:
#           title                                            href  \
# 0  Amber Valley  /news/election/2023/england/councils/E07000032
# 1          Arun  /news/election/2023/england/councils/E07000224
# 2      Ashfield  /news/election/2023/england/councils/E07000170
# 3       Ashford  /news/election/2023/england/councils/E07000105
#
#                                          winnerFlash context
# 0  {'displayMode': 'party', 'year': 2023, 'prevYe...    None
# 1  {'displayMode': 'party', 'year': 2023, 'prevYe...    None
# 2  {'displayMode': 'party', 'year': 2023, 'prevYe...    None
# 3  {'displayMode': 'party', 'year': 2023, 'prevYe...    None

# %% [markdown]
# ## Flattening the JSON
#
# The problem is that there are further 'nested' branches, so that the `winnerFlash` column in the data frame above, for example, contains further JSON.
#
# To deal with this, it's better to use the `json_normalize` function: this flattens sub-branches into separate columns.
#
# When we use that, we can see we get a column called `winnerFlash.displayMode` (the `displayMode` branch of the `winnerFlash` branch) as well as `winnerFlash.year` (the `year` branch of the `winnerFlash` branch), and so on.

# %%
#create a data frame using json_normalize
pd.json_normalize(jsonresponse['groups'][0]['cards'])
# Out:
#           title                                            href context  \
# 0  Amber Valley  /news/election/2023/england/councils/E07000032    None
# 1          Arun  /news/election/2023/england/councils/E07000224    None
# 2      Ashfield  /news/election/2023/england/councils/E07000170    None
# 3       Ashford  /news/election/2023/england/councils/E07000105    None
#
#   winnerFlash.displayMode  winnerFlash.year winnerFlash.prevYear  \
# 0                   party              2023             previous
# 1                   party              2023             previous
# 2                   party              2023             previous
# 3                   party              2023             previous
#
#   winnerFlash.newColour winnerFlash.prevColour              winnerFlash.flash  \
# 0               #E91D0E                #0575C9  LABOUR GAIN FROM CONSERVATIVE
# 1               #646464                #646464              NO PARTY MAJORITY
# 2               #BABABA                #BABABA     ASHFIELD INDEPENDENTS HOLD
# 3               #646464                #646464              NO PARTY MAJORITY
#
#                                winnerFlash.longFlash winnerFlash.textColour  \
# 0                 2023 Labour gain from Conservative                #FFFFFF
# 1  2023 no overall control, no change from previo...                #FFFFFF
# 2  2023 Ashfield Independents hold, from previous...                #3F3F42
# 3  2023 no overall control, no change from previo...                #FFFFFF
#
#    winnerFlash.partyName       winnerFlash.flashBold winnerFlash.flashRegular  \
# 0                 Labour                 LABOUR GAIN        FROM CONSERVATIVE
# 1     no overall control           NO PARTY MAJORITY                NO CHANGE
# 2  Ashfield Independents  ASHFIELD INDEPENDENTS HOLD
# 3     no overall control           NO PARTY MAJORITY                NO CHANGE
#
#   winnerFlash.winnerPartyCode winnerFlash.prevWinnerPartyCode
# 0                         LAB                             CON
# 1                         NOC                             NOC
# 2                         ASH                             ASH
# 3                         NOC                             NOC

# %% [markdown]
# Once we're happy with that, we can store it in a data frame variable.

# %%
#create a data frame using json_normalize - save in cardsdf
cardsdf = pd.json_normalize(jsonresponse['groups'][0]['cards'])
#show variable
cardsdf
# Out:
#           title                                            href context  \
# 0  Amber Valley  /news/election/2023/england/councils/E07000032    None
# 1          Arun  /news/election/2023/england/councils/E07000224    None
# 2      Ashfield  /news/election/2023/england/councils/E07000170    None
# 3       Ashford  /news/election/2023/england/councils/E07000105    None
#
#   winnerFlash.displayMode  winnerFlash.year winnerFlash.prevYear  \
# 0                   party              2023             previous
# 1                   party              2023             previous
# 2                   party              2023             previous
# 3                   party              2023             previous
#
#   winnerFlash.newColour winnerFlash.prevColour              winnerFlash.flash  \
# 0               #E91D0E                #0575C9  LABOUR GAIN FROM CONSERVATIVE
# 1               #646464                #646464              NO PARTY MAJORITY
# 2               #BABABA                #BABABA     ASHFIELD INDEPENDENTS HOLD
# 3               #646464                #646464              NO PARTY MAJORITY
#
#                                winnerFlash.longFlash winnerFlash.textColour  \
# 0                 2023 Labour gain from Conservative                #FFFFFF
# 1  2023 no overall control, no change from previo...                #FFFFFF
# 2  2023 Ashfield Independents hold, from previous...                #3F3F42
# 3  2023 no overall control, no change from previo...                #FFFFFF
#
#    winnerFlash.partyName       winnerFlash.flashBold winnerFlash.flashRegular  \
# 0                 Labour                 LABOUR GAIN        FROM CONSERVATIVE
# 1     no overall control           NO PARTY MAJORITY                NO CHANGE
# 2  Ashfield Independents  ASHFIELD INDEPENDENTS HOLD
# 3     no overall control           NO PARTY MAJORITY                NO CHANGE
#
#   winnerFlash.winnerPartyCode winnerFlash.prevWinnerPartyCode
# 0                         LAB                             CON
# 1                         NOC                             NOC
# 2                         ASH                             ASH
# 3                         NOC                             NOC

# %% [markdown]
# ## Export the results (one group)
#
# We can now export the results as a CSV, before doing some further work.
#
# Pandas has a `.to_csv()` method for converting a data frame to a CSV file, which appears in the Files area on the left of the Colab notebook.
#
# We can download from there manually, but here we import another library -  which allows us to create an automatic download.

# %%
#import a library for downloading files
from google.colab import files

# %%
#export to CSV
cardsdf.to_csv('electioncards.csv')
#start download
files.download('electioncards.csv')

# %% [markdown]
# ## Getting multiple branches
#
# Of course so far we've only got the 'A' branch of the JSON data. To get other branches we need to use a `for` loop.
#
# This loop goes through each branch (from A to Z - or at least Y, as there's no Z branch), flattens the JSON at that branch into a data frame, and adds it to a list.
#
# By the end of the loop we have a list full of data frames, which we can convert into one big data frame.

# %%
#create an empty list to store the results of our loop
listofjson = []

#loop through the items in the 'groups' branch
for i in jsonresponse['groups']:
  #print the 'cards' sub-branch
  print(i['cards'])
  #flatten into a data frame, and store
  flattened_json = pd.json_normalize(i['cards'])
  #add that data frame to the list
  listofjson.append(flattened_json)
# Out:
# [{'title': 'Amber Valley', 'href': '/news/election/2023/england/councils/E07000032', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#E91D0E', 'prevColour': '#0575C9', 'flash': 'LABOUR GAIN FROM CONSERVATIVE', 'longFlash': '2023 Labour gain from Conservative', 'textColour': '#FFFFFF', 'partyName': 'Labour', 'flashBold': 'LABOUR GAIN', 'flashRegular': ' FROM CONSERVATIVE', 'winnerPartyCode': 'LAB', 'prevWinnerPartyCode': 'CON'}, 'context': None}, {'title': 'Arun', 'href': '/news/election/2023/england/councils/E07000224', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#646464', 'flash': 'NO PARTY MAJORITY', 'longFlash': '2023 no overall control, no change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'NO PARTY MAJORITY', 'flashRegular': 'NO CHANGE', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'NOC'}, 'context': None}, {'title': 'Ashfield', 'href': '/news/election/2023/england/councils/E07000170', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#BABABA', 'prevColour': '#BABABA', 'flash': 'ASHFIELD INDEPENDENTS HOLD', 'longFlash': '2023 Ashfield Independents hold, from previous year', 'textColour': '#3F3F42', 'partyName': 'Ashfield Independents', 'flashBold': 'ASHFIELD INDEPENDENTS HOLD', 'flashRegular': '', 'winnerPartyCode': 'ASH', 'prevWinnerPartyCode': 'ASH'}, 'context': None}, {'title': 'Ashford', 'href': '/news/election/2023/england/councils/E07000105', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '
 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#0575C9', 'flash': 'CONSERVATIVE LOSS - NO PARTY MAJORITY', 'longFlash': '2023 Conservative lose to no overall control, change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'CONSERVATIVE LOSS', 'flashRegular': 'NO PARTY MAJORITY', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'CON'}, 'context': None}, {'title': 'Welwyn Hatfield', 'href': '/news/election/2023/england/councils/E07000241', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#646464', 'prevColour': '#0575C9', 'flash': 'CONSERVATIVE LOSS - NO PARTY MAJORITY', 'longFlash': '2023 Conservative lose to no overall control, change from previous year', 'textColour': '#FFFFFF', 'partyName': 'no overall control', 'flashBold': 'CONSERVATIVE LOSS', 'flashRegular': 'NO PARTY MAJORITY', 'winnerPartyCode': 'NOC', 'prevWinnerPartyCode': 'CON'}, 'context': None}, {'title': 'West Berkshire', 'href': '/news/election/2023/england/councils/E06000037', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#EFAC18', 'prevColour': '#0575C9', 'flash': 'LIBERAL DEMOCRAT GAIN FROM CONSERVATIVE', 'longFlash': '2023 Liberal Democrat gain from Conservative, change from previous year', 'textColour': '#3F3F42', 'partyName': 'Liberal Democrat', 'flashBold': 'LIBERAL DEMOCRAT GAIN', 'flashRegular': ' FROM CONSERVATIVE', ...
# [{'title': 'York', 'href': '/news/election/2023/england/councils/E06000014', 'winnerFlash': {'displayMode': 'party', 'year': 2023, 'prevYear': 'previous', 'newColour': '#E91D0E', 'prevColour': '#646464', 'flash': 'LABOUR GAIN FROM NO PARTY MAJORITY', 'longFlash': '2023 Labour gain from no overall control, change from previous year', 'textColour': '#FFFFFF', 'partyName': 'Labour', 'flashBold': 'LABOUR GAIN', 'flashRegular': 'FROM NO PARTY MAJORITY', 'winnerPartyCode': 'LAB', 'prevWinnerPartyCode': 'NOC'}, 'context': None}]

# %%
#how many items in that list now?
len(listofjson)
# Out:
# 22

# %% [markdown]
# ### Join multiple data frames into one
#
# We can join a list of multiple data frames by using pandas's `concat()` function. It takes a list of data frames - which we already have.

# %%
#join a list of data frames and store in a variable called 'allthegroups'
allthegroups = pd.concat(listofjson)
#show the results
allthegroups
# Out:
#            title                                            href context  \
# 0   Amber Valley  /news/election/2023/england/councils/E07000032    None
# 1           Arun  /news/election/2023/england/councils/E07000224    None
# 2       Ashfield  /news/election/2023/england/councils/E07000170    None
# 3        Ashford  /news/election/2023/england/councils/E07000105    None
# 0        Babergh  /news/election/2023/england/councils/E07000200    None
# ..           ...                                             ...     ...
# 21      Worthing  /news/election/2023/england/councils/E07000229    None
# 22      Wychavon  /news/election/2023/england/councils/E07000238    None
# 23          Wyre  /news/election/2023/england/councils/E07000128    None
# 24   Wyre Forest  /news/election/2023/england/councils/E07000239    None
# 0           York  /news/election/2023/england/councils/E06000014    None
#
#    winnerFlash.displayMode  winnerFlash.year winnerFlash.prevYear  \
# 0                    party              2023             previous
# 1                    party              2023             previous
# 2                    party              2023             previous
# 3                    party              2023             previous
# 0                    party              2023             previous
# ..                     ...               ...                  ...
# 21                   party              2023             previous
# 22                   party              2023             previous
# 23                   party              2023             previous
# 24                   party              2023             previous
# 0                    party              2023             previous
#
#    winnerFlash.newColour winnerFlash.prevColour  \
# 0                #E91D0E                #0575C9
# 1                #646464                #646464
# 2                #BABABA                #BABABA
# 3                #646464                #646464
# 0                #646464                #646464
# ..                   ...                    ...
# 21               #E91D0E                #E91D0E
# 22               #0575C9                #0575C9
# 23               #0575C9                #0575C9
# 24               #0575C9                #646464
# 0                #E91D0E                #646464
#
#                            winnerFlash.flash  \
# 0              LABOUR GAIN FROM CONSERVATIVE
# 1                          NO PARTY MAJORITY
# 2                 ASHFIELD INDEPENDENTS HOLD
# 3                          NO PARTY MAJORITY
# 0                          NO PARTY MAJORITY
# ..                                       ...
# 21                               LABOUR HOLD
# 22                         CONSERVATIVE HOLD
# 23                         CONSERVATIVE HOLD
# 24  CONSERVATIVE GAIN FROM NO PARTY MAJORITY
# 0         LABOUR GAIN FROM NO PARTY MAJORITY
#
#                                 winnerFlash.longFlash winnerFlash.textColour  \
# 0                  2023 Labour gain from Conservative                #FFFFFF
# 1   2023 no overall control, no change from previo...                #FFFFFF
# 2   2023 Ashfield Independents hold, from previous...                #3F3F42
# 3   2023 no overall control, no change from previo...                #FFFFFF
# 0   2023 no overall control, no change from previo...                #FFFFFF
# ..                                                ...                    ...
# 21               2023 Labour hold, from previous year                #FFFFFF
# 22                             2023 Conservative hold                #FFFFFF
# 23         2023 Conservative hold, from previous year                #FFFFFF
# 24  2023 Conservative gain from no overall control...                #FFFFFF
# 0   2023 Labour gain from no overall control, chan...                #FFFFFF
#
#     winnerFlash.partyName       winnerFlash.flashBold  \
# 0                  Labour                 LABOUR GAIN
# 1      no overall control           NO PARTY MAJORITY
# 2   Ashfield Independents  ASHFIELD INDEPENDENTS HOLD
# 3      no overall control           NO PARTY MAJORITY
# 0      no overall control           NO PARTY MAJORITY
# ..                    ...                         ...
# 21                 Labour                 LABOUR HOLD
# 22           Conservative           CONSERVATIVE HOLD
# 23           Conservative           CONSERVATIVE HOLD
# 24           Conservative           CONSERVATIVE GAIN
# 0                  Labour                 LABOUR GAIN
#
#    winnerFlash.flashRegular winnerFlash.winnerPartyCode  \
# 0         FROM CONSERVATIVE                         LAB
# 1                 NO CHANGE                         NOC
# 2                                                   ASH
# 3                 NO CHANGE                         NOC
# 0                 NO CHANGE                         NOC
# ..                      ...                         ...
# 21                                                  LAB
# 22                                                  CON
# 23                                                  CON
# 24   FROM NO PARTY MAJORITY                         CON
# 0    FROM NO PARTY MAJORITY                         LAB
#
#    winnerFlash.prevWinnerPartyCode
# 0                              CON
# 1                              NOC
# 2                              ASH
# 3                              NOC
# 0                              NOC
# ..                             ...
# 21                             LAB
# 22                             CON
# 23                             CON
# 24                             NOC
# 0                              NOC
#
# [230 rows x 16 columns]

# %% [markdown]
# ## Export the results (all groups)
#
# Now we can export the resulting data frame that contains all groups' data.

# %%
#convert data frame to CSV
allthegroups.to_csv('allthegroups.csv')
#download the file
files.download('allthegroups.csv')
